# %% [markdown]
# Proyek Analisis Data

# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Fattahur Rohim
# - **Email:** mc129d5y1922@student.devacademy.id
# - **ID Dicoding:** mc129d5y1922
#
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana Tren Air Quality Index (AQI) di beberapa kota
# - Pertanyaan 2: Bagaimana pengaruh suhu, kelembapan, dan kecepatan angin terhadap tingkat polusi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
shunyi_df = pd.read_csv("dataset/PRSA_Data_Shunyi_20130301-20170228.csv") # Memuat data air quality Shunyi
tiantan_df = pd.read_csv("dataset/PRSA_Data_Tiantan_20130301-20170228.csv") # Memuat data air quality Tiantan
wanliu_df = pd.read_csv("dataset/PRSA_Data_Wanliu_20130301-20170228.csv") # Memuat data air quality Wanliu

shunyi_df.head(), tiantan_df.head(), wanliu_df.head()
# Out:
# (   No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
#  0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
#  1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
#  2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
#  3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
#  4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#       PRES  DEWP  RAIN  wd  WSPM station
#  0  1025.8 -20.5   0.0  NW   9.3  Shunyi
#  1  1026.1 -21.3   0.0  NW   9.4  Shunyi
#  2  1026.2 -23.0   0.0  NW   8.6  Shunyi
#  3  1027.3 -23.3   0.0  NW   6.6  Shunyi
#  4  1027.7 -22.9   0.0  NW   4.5  Shunyi  ,
#     No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
#  0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
#  1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# ...

# %% [markdown]
# **Insight:**
# - Ketiga dataframe tersebut memiliki struktur yang sama

# %% [markdown]
# ### Assessing Data

# %%
# Menilai dataframe Shunyi
shunyi_df.info(), shunyi_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# (None,
#  No            0
# ...

# %%
# Menilai dataframe tiantan
tiantan_df.info(), tiantan_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# (None,
#  No            0
# ...

# %%
# Menilai dataframe wanliu
wanliu_df.info(), wanliu_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# (None,
#  No            0
# ...

# %%
# Cek duplikasi pada masing masing dataframe

# Cek duplikasi pada dataframe Shunyi
print("Jumlah duplikasi data pada dataframe Shunyi: ", shunyi_df.duplicated().sum())

# Cek duplikasi pada dataframe Tiantan
print("Jumlah duplikasi data pada dataframe Tiantan: ", tiantan_df.duplicated().sum())

# Cek duplikasi pada dataframe Wanliu
print("Jumlah duplikasi data pada dataframe Wanliu: ", wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataframe Shunyi:  0
# Jumlah duplikasi data pada dataframe Tiantan:  0
# Jumlah duplikasi data pada dataframe Wanliu:  0

# %%
# Describe masing masing dataframe

# Dataframe shunyi
shunyi_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
# Dataframe tiantan
tiantan_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
# Dataframe shunyi
wanliu_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %% [markdown]
# **Insight:**
# - Pada masing-masing dataframe terdapat beberapa kolom data yang memiliki missing value
# - Kolom yang memiliki missing value adalah kolom yang sama
# - Tidak ada duplikasi data pada ketiga dataframe tersebut

# %% [markdown]
# ### Cleaning Data

# %%
# Cleansing untuk dataframe shunyi

shunyi_df["datetime"] = pd.to_datetime(shunyi_df[["year", "month", "day", "hour"]]) # Untuk menggabungkan kolom tersebut menjadi satu kolom datetime
shunyi_df.drop(columns=["year", "month", "day", "hour"], inplace=True) # Untuk menghapus kolom yang sudah digabungkan

# %%
num_cols = shunyi_df.select_dtypes(include=["float64"]).columns
shunyi_df[num_cols] = shunyi_df[num_cols].apply(lambda x: x.fillna(x.median())) # Untuk mengisi misssing value dengan median dari kolom tersebut

# %%
# Cleansing kolom wind direction (wd) pada shunyi dataframe
shunyi_df["wd"].fillna(shunyi_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus
# Out:
# C:\Users\fatta\AppData\Local\Temp\ipykernel_3508\2735130533.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_df["wd"].fillna(shunyi_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus

# %%
# Crosscheck kembali hasil cleansing shunyig dataframe
shunyi_df.info(), shunyi_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        35064 non-null  int64
#  1   PM2.5     35064 non-null  float64
#  2   PM10      35064 non-null  float64
#  3   SO2       35064 non-null  float64
#  4   NO2       35064 non-null  float64
#  5   CO        35064 non-null  float64
#  6   O3        35064 non-null  float64
#  7   TEMP      35064 non-null  float64
#  8   PRES      35064 non-null  float64
#  9   DEWP      35064 non-null  float64
#  10  RAIN      35064 non-null  float64
#  11  wd        35064 non-null  object
#  12  WSPM      35064 non-null  float64
#  13  station   35064 non-null  object
#  14  datetime  35064 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 4.0+ MB
# (None,
#                   No         PM2.5          PM10           SO2           NO2  \
# ...

# %%
# Cleansing dataframe Tiantan

tiantan_df["datetime"] = pd.to_datetime(tiantan_df[["year", "month", "day", "hour"]]) # Untuk menggabungkan kolom tersebut menjadi satu kolom datetime
tiantan_df.drop(columns=["year", "month", "day", "hour"], inplace=True) # Untuk menghapus kolom yang sudah digabungkan

# %%
num_cols = tiantan_df.select_dtypes(include=["float64"]).columns
tiantan_df[num_cols] = tiantan_df[num_cols].apply(lambda x: x.fillna(x.median())) # Untuk mengisi misssing value dengan median dari kolom tersebut

# %%
# Cleansing kolom wind direction (wd) pada shunyi dataframe
tiantan_df["wd"].fillna(tiantan_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus
# Out:
# C:\Users\fatta\AppData\Local\Temp\ipykernel_3508\1433453874.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_df["wd"].fillna(tiantan_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus

# %%
# Crosscheck kembali hasil cleansing Tiantan dataframe
tiantan_df.info(), tiantan_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        35064 non-null  int64
#  1   PM2.5     35064 non-null  float64
#  2   PM10      35064 non-null  float64
#  3   SO2       35064 non-null  float64
#  4   NO2       35064 non-null  float64
#  5   CO        35064 non-null  float64
#  6   O3        35064 non-null  float64
#  7   TEMP      35064 non-null  float64
#  8   PRES      35064 non-null  float64
#  9   DEWP      35064 non-null  float64
#  10  RAIN      35064 non-null  float64
#  11  wd        35064 non-null  object
#  12  WSPM      35064 non-null  float64
#  13  station   35064 non-null  object
#  14  datetime  35064 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 4.0+ MB
# (None,
#                   No         PM2.5          PM10           SO2           NO2  \
# ...

# %%
# Cleansing dataframe Wanliu

wanliu_df["datetime"] = pd.to_datetime(wanliu_df[["year", "month", "day", "hour"]]) # Untuk menggabungkan kolom tersebut menjadi satu kolom datetime
wanliu_df.drop(columns=["year", "month", "day", "hour"], inplace=True) # Untuk menghapus kolom yang sudah digabungkan

# %%
num_cols = wanliu_df.select_dtypes(include=["float64"]).columns
wanliu_df[num_cols] = wanliu_df[num_cols].apply(lambda x: x.fillna(x.median())) # Untuk mengisi misssing value dengan median dari kolom tersebut

# %%
# Cleansing kolom wind direction (wd) pada shunyi dataframe
wanliu_df["wd"].fillna(wanliu_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus
# Out:
# C:\Users\fatta\AppData\Local\Temp\ipykernel_3508\1510177474.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_df["wd"].fillna(wanliu_df["wd"].mode()[0], inplace=True) # Mengisi missing value pada kolom wd dengan nilai modus

# %%
# Crosscheck kembali hasil cleansing Wanliu dataframe
wanliu_df.info(), wanliu_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        35064 non-null  int64
#  1   PM2.5     35064 non-null  float64
#  2   PM10      35064 non-null  float64
#  3   SO2       35064 non-null  float64
#  4   NO2       35064 non-null  float64
#  5   CO        35064 non-null  float64
#  6   O3        35064 non-null  float64
#  7   TEMP      35064 non-null  float64
#  8   PRES      35064 non-null  float64
#  9   DEWP      35064 non-null  float64
#  10  RAIN      35064 non-null  float64
#  11  wd        35064 non-null  object
#  12  WSPM      35064 non-null  float64
#  13  station   35064 non-null  object
#  14  datetime  35064 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 4.0+ MB
# (None,
#                   No         PM2.5          PM10           SO2           NO2  \
# ...

# %%
# Crosscheck kembali untuk melihat apakah ada duplikasi pada masing masing dataframe

# Cek duplikasi pada dataframe Shunyi
print("Jumlah duplikasi data pada dataframe Shunyi: ", shunyi_df.duplicated().sum())

# Cek duplikasi pada dataframe Tiantan
print("Jumlah duplikasi data pada dataframe Tiantan: ", tiantan_df.duplicated().sum())

# Cek duplikasi pada dataframe Wanliu
print("Jumlah duplikasi data pada dataframe Wanliu: ", wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataframe Shunyi:  0
# Jumlah duplikasi data pada dataframe Tiantan:  0
# Jumlah duplikasi data pada dataframe Wanliu:  0

# %% [markdown]
# **Insight:**
# - Dari ketiga dataframe tersebut, ketiganya memiliki missing value pada kolom yang sama yakni kolom kolom polutan udara dan wind direction
# - Ketiga dataframe tersebut tidak ditemukan duplikasi data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Menggabungkan ketiga dataframe 
all_df = pd.concat([shunyi_df, tiantan_df, wanliu_df], axis=0, ignore_index=True)

# %%
# Melihat hasil penggabungan dari ketiga dataframe tersebut

all_df.head(), all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105192 entries, 0 to 105191
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   No        105192 non-null  int64
#  1   PM2.5     105192 non-null  float64
#  2   PM10      105192 non-null  float64
#  3   SO2       105192 non-null  float64
#  4   NO2       105192 non-null  float64
#  5   CO        105192 non-null  float64
#  6   O3        105192 non-null  float64
#  7   TEMP      105192 non-null  float64
#  8   PRES      105192 non-null  float64
#  9   DEWP      105192 non-null  float64
#  10  RAIN      105192 non-null  float64
#  11  wd        105192 non-null  object
#  12  WSPM      105192 non-null  float64
#  13  station   105192 non-null  object
#  14  datetime  105192 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 12.0+ MB
# (   No  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN  wd  \
# ...

# %%
all_df.groupby(by="station").agg({
    "PM2.5": ["max", "min", "mean", "std"],
    "PM10": ["max", "min", "mean", "std"],
    'SO2': ["max", "min", "mean", "std"], 
    'NO2': ["max", "min", "mean", "std"], 
    'CO': ["max", "min", "mean", "std"], 
    'O3': ["max", "min", "mean", "std"]
}) # Melihat distribusi data polutan pada masing masing station
# Out:
#          PM2.5                              PM10                              \
#            max  min       mean        std    max  min        mean        std
# station
# Shunyi   941.0  2.0  78.853887  80.261997  999.0  2.0   98.397308  88.485447
# Tiantan  821.0  3.0  81.717653  80.199730  988.0  2.0  105.999934  88.976174
# Wanliu   957.0  2.0  83.109169  81.497468  951.0  2.0  110.282666  92.440427
#
#            SO2          ...        NO2                  CO         \
#            max     min  ...       mean        std      max    min
# station                 ...
# Shunyi   239.0  0.2856  ...  43.639911  30.416857  10000.0  100.0
# Tiantan  273.0  0.5712  ...  53.031884  31.617950  10000.0  100.0
# Wanliu   282.0  0.2856  ...  65.098314  37.422775  10000.0  100.0
#
#                                          O3
#                 mean          std       max     min       mean        std
# station
# Shunyi   1163.021504  1123.773397  351.7164  0.2142  54.683189  53.752281
# ...

# %%
all_df.groupby(by="station").agg({
    "RAIN": ["max", "min", "mean", "std"],
}) # Melihat Distribusi data rain pada masing-masing station
# Out:
#          RAIN
#           max  min      mean       std
# station
# Shunyi   37.3  0.0  0.061006  0.761118
# Tiantan  46.4  0.0  0.063983  0.786059
# Wanliu   72.5  0.0  0.068224  0.896471

# %% [markdown]
# **Insight:**
# - Dikarenakan ketiga dataframe yang saya gunakan memiliki struktur kolom yang sama, saya menggabungkan ketiga dataframe tersebut menjadi satu dataframe

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1 (Bagaimana Tren Air Quality Index (AQI)):

# %%
# Menentukan Tren air quality berdasarkan tingkat polutan

# Mencari nilai rata-rata dari semua polutan tiap tahun di masing-masing station
pollutants = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]
annual_pollutants = all_df.groupby([all_df["datetime"].dt.year, 'station'])[pollutants].mean().reset_index()

annual_pollutants.set_index("datetime", inplace=True)
annual_pollutants.head()
# Out:
#           station      PM2.5        PM10        SO2        NO2           CO  \
# datetime
# 2013       Shunyi  76.406318   94.470044  15.045248  41.583896  1171.457789
# 2013      Tiantan  83.144063  108.200708  18.160085  53.287145  1291.464869
# 2013       Wanliu  91.502451  112.221609  23.592475  68.472016  1189.412173
# 2014       Shunyi  83.938710  110.549281  17.219041  45.013710  1154.646119
# 2014      Tiantan  85.478470  113.386621  18.369886  55.295034  1294.771689
#
#                  O3
# datetime
# 2013      56.357005
# 2013      54.100533
# 2013      46.866815
# 2014      58.065788
# 2014      56.181050

# %%
# Membuat visualisasi data berdasarkan dataframe annual pollutants

plt.figure(figsize=(16, 10))
for i, pollutant in enumerate(pollutants, 1):
    plt.subplot(3, 2, i)
    for station in annual_pollutants['station'].unique():
        subset = annual_pollutants[annual_pollutants['station'] == station]
        plt.plot(subset.index, subset[pollutant], marker='o', label=station)

    plt.title(f'Tren {pollutant} per tahun')
    plt.xlabel("Tahun")
    plt.ylabel(f"Konsentrasi {pollutant}")
    plt.grid(alpha=0.3)
    plt.legend(title='Stasiun')

plt.tight_layout()
plt.show()

annual_pollutants.head() # Menampilkan beberapa contoh data untuk analisis
# Out:
#           station      PM2.5        PM10        SO2        NO2           CO  \
# datetime
# 2013       Shunyi  76.406318   94.470044  15.045248  41.583896  1171.457789
# 2013      Tiantan  83.144063  108.200708  18.160085  53.287145  1291.464869
# 2013       Wanliu  91.502451  112.221609  23.592475  68.472016  1189.412173
# 2014       Shunyi  83.938710  110.549281  17.219041  45.013710  1154.646119
# 2014      Tiantan  85.478470  113.386621  18.369886  55.295034  1294.771689
#
#                  O3
# datetime
# 2013      56.357005
# 2013      54.100533
# 2013      46.866815
# 2014      58.065788
# 2014      56.181050

# %% [markdown]
# ### Pertanyaan 2 (Bagaimana pengaruh parameter cuaca terhadap tingkat polusi?):

# %%
# Menghitung korelasi antar polutan dengan parameter cuaca
correlation = all_df[["PM2.5", "PM10", "SO2", "NO2", "CO", "O3", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]].corr()

# %%
# Buat heatmap untuk visualisasi korelasi

plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, fmt='.2f', cmap="coolwarm")
plt.title("Heatmap Korelasi Polutan dan Parameter Cuaca")
plt.show()

# Menampilkan korelasi
correlation
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.887592  0.447999  0.633489  0.754554 -0.151095 -0.133380
# PM10   0.887592  1.000000  0.439752  0.636571  0.682915 -0.126787 -0.107198
# SO2    0.447999  0.439752  1.000000  0.490310  0.484960 -0.124083 -0.283785
# NO2    0.633489  0.636571  0.490310  1.000000  0.652365 -0.472803 -0.293599
# CO     0.754554  0.682915  0.484960  0.652365  1.000000 -0.290631 -0.329081
# O3    -0.151095 -0.126787 -0.124083 -0.472803 -0.290631  1.000000  0.576094
# TEMP  -0.133380 -0.107198 -0.283785 -0.293599 -0.329081  0.576094  1.000000
# PRES   0.002998 -0.028308  0.187931  0.128016  0.170410 -0.419328 -0.827406
# DEWP   0.111464  0.068304 -0.246945 -0.063774 -0.070532  0.287947  0.821418
# RAIN  -0.011986 -0.026604 -0.037756 -0.049676 -0.013507  0.021185  0.038049
# WSPM  -0.265900 -0.184920 -0.077421 -0.392769 -0.285127  0.316920  0.041660
#
#            PRES      DEWP      RAIN      WSPM
# ...

# %% [markdown]
# **Insight:**
# - Pada pertanyaan pertama saya menggunakan line chart untuk mendapatkan visualisasi persebaran/distribusi data polutan dari ketiga dataset
# - Pada pertanyaan kedua saya menggunakan heatmap untuk mendapatkan insight baru dari korelasi polutan dengan parameter cuaca

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Download all dataframe 
all_df.to_csv("all_data.csv", index=False)

# Menggunakan teknik binning untuk mendapatkan air quality index tiap musim
binning_df = all_df.copy()
binning_df["month"] = binning_df["datetime"].dt.month

def get_season(month):
    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    else:
        return 'Winter'

# Tambah kolom season pada dataframe
binning_df["season"] = binning_df["month"].apply(get_season)

# Mengelompokkan data berdasarkan season dan station
seasonal_avg = binning_df.groupby(['station', 'season'])[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].mean().reset_index()

# Membuat visualisasi rata-rata polutan per musim untuk tiap kota
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
seasons = ['Spring', 'Summer', 'Fall', 'Winter']

for i, pollutant in enumerate(pollutants):
    ax = axes[i // 3, i % 3]
    for station in binning_df['station'].unique():
        data = seasonal_avg[seasonal_avg['station'] == station]
        ax.plot(seasons, data[pollutant], marker='o', label=station)
    ax.set_title(f'{pollutant} Average per Season')
    ax.set_xlabel('Season')
    ax.set_ylabel('Concentration')
    ax.legend()

plt.tight_layout()
plt.show()

# Menampilkan beberapa baris hasil binning sebagai contoh
seasonal_avg.head()
# Out:
#    station  season      PM2.5        PM10        SO2        NO2           CO  \
# 0   Shunyi    Fall  78.997848   97.971658   8.291104  47.113890  1159.420215
# 1   Shunyi  Spring  77.645788  112.141157  16.461257  46.072336   953.169497
# 2   Shunyi  Summer  65.357111   77.596332   4.266205  29.457915   867.979846
# 3   Shunyi  Winter  93.698742  106.020464  24.155652  52.114464  1681.336565
# 4  Tiantan    Fall  83.683265  104.136115   8.707332  58.220123  1310.152358
#
#           O3
# 0  32.333836
# 1  65.142322
# 2  88.938965
# 3  31.636314
# 4  32.342832

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Dari visualisasi data tersebut dapat disimpulkan bahwa Kota wanliu adalah kota dengan polusi terbanyak dibandingkan dua kota lainnya. Hal itu bisa dipertanggungjawabkan karena 5 dari 6 line chart yang ditampilkan Kota wanliu berada di atas kota-kota lainnya. Sedangkan Kota shunyi adalah kota dengan polutan paling minim dikarenakan pada line chart tersebut hanya pada chart O3 saja yang berada di puncak
# - Conclution pertanyaan 2: Berdasarkan heatmap korelasi polutan dengan parameter cuaca didapatkan beberapa hasil korelasi contohnya beberapa polutan seperti PM2.5, PM10, CO, NO2 memiliki keterkaitan satu sama lain yang kuat dikarenakan hasil dari heatmap tersebut memiliki hasil yang cukup kuat. Lalu terdapat juga hasil korelasi Kecepatan Angin (WSPM) dengan PM2.5(-0.26) dan NO2(-0.39) memiliki korelasi negatif yang berarti angin dapat membantu menyebarkan polutan di udara
